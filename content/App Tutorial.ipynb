# %% [markdown]
# # <center>  KSU WHEAT LABELS GEN & DATA UPLOADING APPS </center>
#  ### <center> Deployment: **Nicolas Giordano** <center>
#  ##### <center> Guidance and contributions: **Andres Patrignani, PhD** <center>
#
# Welcome, Bem-vindo, Bienvenido to **KSU WHEAT LABELS GEN & DATA UPLOADING APPS**!!
#
# This apps were deployed as part of the semester projet for AGRON 845 at Kansas State University.
#
# If you are reading this tutorial it is because probably is your first time in running the apps or you found some issues!. Any issues, debugs can be reported to Nicolas Giordano at ngiordano@ksu.edu.
#
# A video tutorial on [how to use KSU WHEAT App](https://youtu.be/oZspneaWIgI) is uploaded in YouTube

# %% [markdown]
#  ## Libraries instalation
#
# If this is your first time running the app in your computer you should install the following libraries below

# %%
# !pip install streamlit
# !pip install pandas
# !pip install qrcode
# !pip install reportlab
# !pip install PyPDF2==2.2.0
# !pip install pypdf 
# !pip install numpy
# !pip install streamlit_option_menu
# !pip install streamlit_multipage
# !pip install matplotlib
# !pip install pyproj==3.6.1
# !pip install geopandas==0.14.4
# !pip install simplekml==1.3.6
# !pip install geographiclib==2.0
# !pip install opencv-python==4.10.0.84
# Out:
# Requirement already satisfied: streamlit in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (1.45.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (2.1.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit) (1.31.0)
# Requirement already satisfied: colorama in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit) (2025.4.26)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit) (3.0.2)
# Requirement already satisfied: pandas in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting qrcode
#   Downloading qrcode-8.2-py3-none-any.whl.metadata (17 kB)
# Requirement already satisfied: colorama in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from qrcode) (0.4.6)
# Downloading qrcode-8.2-py3-none-any.whl (45 kB)
# Installing collected packages: qrcode
# Successfully installed qrcode-8.2
# Collecting reportlab
#   Downloading reportlab-4.4.3-py3-none-any.whl.metadata (1.7 kB)
# Requirement already satisfied: pillow>=9.0.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from reportlab) (11.1.0)
# Requirement already satisfied: charset-normalizer in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from reportlab) (3.3.2)
# Downloading reportlab-4.4.3-py3-none-any.whl (2.0 MB)
#    ---------------------------------------- 0.0/2.0 MB ? eta -:--:--
#    ----- ---------------------------------- 0.3/2.0 MB ? eta -:--:--
#    ---------------------------------------- 2.0/2.0 MB 8.8 MB/s eta 0:00:00
# Installing collected packages: reportlab
# Successfully installed reportlab-4.4.3
# Collecting PyPDF2==2.2.0
#   Downloading PyPDF2-2.2.0-py3-none-any.whl.metadata (5.7 kB)
# Downloading PyPDF2-2.2.0-py3-none-any.whl (189 kB)
# Installing collected packages: PyPDF2
# Successfully installed PyPDF2-2.2.0
# Collecting pypdf
#   Downloading pypdf-5.9.0-py3-none-any.whl.metadata (7.1 kB)
# Downloading pypdf-5.9.0-py3-none-any.whl (313 kB)
# Installing collected packages: pypdf
# Successfully installed pypdf-5.9.0
# Requirement already satisfied: numpy in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (2.1.3)
# Collecting streamlit_option_menu
#   Downloading streamlit_option_menu-0.4.0-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: streamlit>=1.36 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit_option_menu) (1.45.1)
# Requirement already satisfied: altair<6,>=4.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (1.9.0)
# Requirement already satisfied: cachetools<6,>=4.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (8.1.8)
# Requirement already satisfied: numpy<3,>=1.23 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (2.1.3)
# Requirement already satisfied: packaging<25,>=20 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (24.2)
# Requirement already satisfied: pandas<3,>=1.4.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (2.2.3)
# Requirement already satisfied: pillow<12,>=7.1.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (11.1.0)
# Requirement already satisfied: protobuf<7,>=3.20 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (5.29.3)
# Requirement already satisfied: pyarrow>=7.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (19.0.0)
# Requirement already satisfied: requests<3,>=2.27 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (2.32.3)
# Requirement already satisfied: tenacity<10,>=8.1.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (9.0.0)
# Requirement already satisfied: toml<2,>=0.10.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (0.10.2)
# Requirement already satisfied: typing-extensions<5,>=4.4.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (4.12.2)
# Requirement already satisfied: watchdog<7,>=2.1.5 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (4.0.2)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (3.1.43)
# Requirement already satisfied: tornado<7,>=6.0.3 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from streamlit>=1.36->streamlit_option_menu) (6.5.1)
# Requirement already satisfied: jinja2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit_option_menu) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit_option_menu) (4.23.0)
# Requirement already satisfied: narwhals>=1.14.2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from altair<6,>=4.0->streamlit>=1.36->streamlit_option_menu) (1.31.0)
# Requirement already satisfied: colorama in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from click<9,>=7.0->streamlit>=1.36->streamlit_option_menu) (0.4.6)
# Requirement already satisfied: gitdb<5,>=4.0.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit_option_menu) (4.0.7)
# Requirement already satisfied: smmap<5,>=3.0.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit>=1.36->streamlit_option_menu) (4.0.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit_option_menu) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit_option_menu) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas<3,>=1.4.0->streamlit>=1.36->streamlit_option_menu) (2025.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit_option_menu) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit_option_menu) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit_option_menu) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from requests<3,>=2.27->streamlit>=1.36->streamlit_option_menu) (2025.4.26)
# Requirement already satisfied: attrs>=22.2.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit_option_menu) (24.3.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit_option_menu) (2023.7.1)
# Requirement already satisfied: referencing>=0.28.4 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit_option_menu) (0.30.2)
# Requirement already satisfied: rpds-py>=0.7.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jsonschema>=3.0->altair<6,>=4.0->streamlit>=1.36->streamlit_option_menu) (0.22.3)
# Requirement already satisfied: six>=1.5 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit>=1.36->streamlit_option_menu) (1.17.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from jinja2->altair<6,>=4.0->streamlit>=1.36->streamlit_option_menu) (3.0.2)
# Downloading streamlit_option_menu-0.4.0-py3-none-any.whl (829 kB)
#    ---------------------------------------- 0.0/829.3 kB ? eta -:--:--
#    ------------ --------------------------- 262.1/829.3 kB ? eta -:--:--
#    ---------------------------------------- 829.3/829.3 kB 6.3 MB/s eta 0:00:00
# Installing collected packages: streamlit_option_menu
# Successfully installed streamlit_option_menu-0.4.0
# Collecting streamlit_multipage
#   Downloading streamlit_multipage-0.0.18-py3-none-any.whl.metadata (11 kB)
# Downloading streamlit_multipage-0.0.18-py3-none-any.whl (19 kB)
# Installing collected packages: streamlit_multipage
# Successfully installed streamlit_multipage-0.0.18
# Requirement already satisfied: matplotlib in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (3.10.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from matplotlib) (4.55.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: numpy>=1.23 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: packaging>=20.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from matplotlib) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from matplotlib) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Collecting pyproj==3.6.1
#   Downloading pyproj-3.6.1.tar.gz (225 kB)
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   Getting requirements to build wheel did not run successfully.
#   exit code: 1
#
#   [1 lines of output]
#   proj executable not found. Please set the PROJ_DIR variable. For more information see: https://pyproj4.github.io/pyproj/stable/installation.html
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# Getting requirements to build wheel did not run successfully.
# exit code: 1
#
# See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Collecting geopandas==0.14.4
#   Downloading geopandas-0.14.4-py3-none-any.whl.metadata (1.5 kB)
# Collecting fiona>=1.8.21 (from geopandas==0.14.4)
#   Downloading fiona-1.10.1-cp313-cp313-win_amd64.whl.metadata (58 kB)
# Requirement already satisfied: numpy>=1.22 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from geopandas==0.14.4) (2.1.3)
# Requirement already satisfied: packaging in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from geopandas==0.14.4) (24.2)
# Requirement already satisfied: pandas>=1.4.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from geopandas==0.14.4) (2.2.3)
# Collecting pyproj>=3.3.0 (from geopandas==0.14.4)
#   Downloading pyproj-3.7.1-cp313-cp313-win_amd64.whl.metadata (31 kB)
# Collecting shapely>=1.8.0 (from geopandas==0.14.4)
#   Downloading shapely-2.1.1-cp313-cp313-win_amd64.whl.metadata (7.0 kB)
# Requirement already satisfied: attrs>=19.2.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas==0.14.4) (24.3.0)
# Requirement already satisfied: certifi in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas==0.14.4) (2025.4.26)
# Requirement already satisfied: click~=8.0 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from fiona>=1.8.21->geopandas==0.14.4) (8.1.8)
# Collecting click-plugins>=1.0 (from fiona>=1.8.21->geopandas==0.14.4)
#   Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl.metadata (6.5 kB)
# Collecting cligj>=0.5 (from fiona>=1.8.21->geopandas==0.14.4)
#   Downloading cligj-0.7.2-py3-none-any.whl.metadata (5.0 kB)
# Requirement already satisfied: colorama in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from click~=8.0->fiona>=1.8.21->geopandas==0.14.4) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas==0.14.4) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas==0.14.4) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from pandas>=1.4.0->geopandas==0.14.4) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas>=1.4.0->geopandas==0.14.4) (1.17.0)
# Downloading geopandas-0.14.4-py3-none-any.whl (1.1 MB)
#    ---------------------------------------- 0.0/1.1 MB ? eta -:--:--
#    --------- ------------------------------ 0.3/1.1 MB ? eta -:--:--
#    ---------------------------------------- 1.1/1.1 MB 5.4 MB/s eta 0:00:00
# Downloading fiona-1.10.1-cp313-cp313-win_amd64.whl (24.5 MB)
#    ---------------------------------------- 0.0/24.5 MB ? eta -:--:--
#    ----- ---------------------------------- 3.4/24.5 MB 15.8 MB/s eta 0:00:02
#    ----------- ---------------------------- 6.8/24.5 MB 16.2 MB/s eta 0:00:02
#    --------------- ------------------------ 9.4/24.5 MB 14.7 MB/s eta 0:00:02
#    ------------------- -------------------- 11.8/24.5 MB 13.9 MB/s eta 0:00:01
#    ----------------------- ---------------- 14.2/24.5 MB 13.4 MB/s eta 0:00:01
#    --------------------------- ------------ 16.5/24.5 MB 13.1 MB/s eta 0:00:01
#    ------------------------------ --------- 18.9/24.5 MB 12.7 MB/s eta 0:00:01
#    ---------------------------------- ----- 21.2/24.5 MB 12.6 MB/s eta 0:00:01
#    -------------------------------------- - 23.3/24.5 MB 12.5 MB/s eta 0:00:01
#    ---------------------------------------- 24.5/24.5 MB 12.0 MB/s eta 0:00:00
# Downloading click_plugins-1.1.1.2-py2.py3-none-any.whl (11 kB)
# Downloading cligj-0.7.2-py3-none-any.whl (7.1 kB)
# Downloading pyproj-3.7.1-cp313-cp313-win_amd64.whl (6.3 MB)
#    ---------------------------------------- 0.0/6.3 MB ? eta -:--:--
#    --------------------- ------------------ 3.4/6.3 MB 17.0 MB/s eta 0:00:01
#    ---------------------------------------- 6.3/6.3 MB 16.1 MB/s eta 0:00:00
# Downloading shapely-2.1.1-cp313-cp313-win_amd64.whl (1.7 MB)
#    ---------------------------------------- 0.0/1.7 MB ? eta -:--:--
#    ---------------------------------------- 1.7/1.7 MB 14.7 MB/s eta 0:00:00
# Installing collected packages: shapely, pyproj, cligj, click-plugins, fiona, geopandas
#
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ---------------------------------------- 0/6 [shapely]
#    ------ --------------------------------- 1/6 [pyproj]
#    ------ --------------------------------- 1/6 [pyproj]
#    ------ --------------------------------- 1/6 [pyproj]
#    -------------------------- ------------- 4/6 [fiona]
#    -------------------------- ------------- 4/6 [fiona]
#    -------------------------- ------------- 4/6 [fiona]
#    -------------------------- ------------- 4/6 [fiona]
#    -------------------------- ------------- 4/6 [fiona]
#    -------------------------- ------------- 4/6 [fiona]
#    -------------------------- ------------- 4/6 [fiona]
#    --------------------------------- ------ 5/6 [geopandas]
#    --------------------------------- ------ 5/6 [geopandas]
#    --------------------------------- ------ 5/6 [geopandas]
#    --------------------------------- ------ 5/6 [geopandas]
#    ---------------------------------------- 6/6 [geopandas]
#
# Successfully installed click-plugins-1.1.1.2 cligj-0.7.2 fiona-1.10.1 geopandas-0.14.4 pyproj-3.7.1 shapely-2.1.1
# Collecting simplekml==1.3.6
#   Downloading simplekml-1.3.6.tar.gz (52 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: simplekml
#   Building wheel for simplekml (setup.py): started
#   Building wheel for simplekml (setup.py): finished with status 'done'
#   Created wheel for simplekml: filename=simplekml-1.3.6-py3-none-any.whl size=65874 sha256=b9a6a806d57aa0431cdc0cfd89001e2922bfd71b1cfad86bba7164c3f6509bec
#   Stored in directory: c:\users\jgastaldi\appdata\local\pip\cache\wheels\fd\2a\d1\84a7abdbb59566c442beb1b4fb946fe1e26c5a48fd1d5e0763
# Successfully built simplekml
# Installing collected packages: simplekml
# Successfully installed simplekml-1.3.6
#   DEPRECATION: Building 'simplekml' using the legacy setup.py bdist_wheel mechanism, which will be removed in a future version. pip 25.3 will enforce this behaviour change. A possible replacement is to use the standardized build interface by setting the `--use-pep517` option, (possibly combined with `--no-build-isolation`), or adding a `pyproject.toml` file to the source tree of 'simplekml'. Discussion can be found at https://github.com/pypa/pip/issues/6334
# Collecting geographiclib==2.0
#   Downloading geographiclib-2.0-py3-none-any.whl.metadata (1.4 kB)
# Downloading geographiclib-2.0-py3-none-any.whl (40 kB)
# Installing collected packages: geographiclib
# Successfully installed geographiclib-2.0
# Collecting opencv-python==4.10.0.84
#   Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\jgastaldi\appdata\local\anaconda3\lib\site-packages (from opencv-python==4.10.0.84) (2.1.3)
# Downloading opencv_python-4.10.0.84-cp37-abi3-win_amd64.whl (38.8 MB)
#    ---------------------------------------- 0.0/38.8 MB ? eta -:--:--
#     --------------------------------------- 0.5/38.8 MB 4.9 MB/s eta 0:00:08
#    --- ------------------------------------ 3.1/38.8 MB 11.3 MB/s eta 0:00:04
#    ------ --------------------------------- 6.6/38.8 MB 13.4 MB/s eta 0:00:03
#    --------- ------------------------------ 9.7/38.8 MB 13.8 MB/s eta 0:00:03
#    ------------ --------------------------- 12.1/38.8 MB 13.2 MB/s eta 0:00:03
#    -------------- ------------------------- 14.4/38.8 MB 12.9 MB/s eta 0:00:02
#    ----------------- ---------------------- 16.8/38.8 MB 12.6 MB/s eta 0:00:02
#    ------------------- -------------------- 19.1/38.8 MB 12.5 MB/s eta 0:00:02
#    ---------------------- ----------------- 21.5/38.8 MB 12.4 MB/s eta 0:00:02
#    ------------------------ --------------- 23.9/38.8 MB 12.2 MB/s eta 0:00:02
#    -------------------------- ------------- 26.2/38.8 MB 12.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 28.6/38.8 MB 12.1 MB/s eta 0:00:01
#    ------------------------------- -------- 30.9/38.8 MB 12.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 33.3/38.8 MB 11.9 MB/s eta 0:00:01
#    ------------------------------------ --- 35.7/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------  38.0/38.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------------- 38.8/38.8 MB 11.7 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.10.0.84

# %% [markdown]
# ## Running the app
#
# Once all the requiered libraries were correctly loaded, let's proceed running the app.
#
#    1. Open a new terminal. For opening a new terminal, go the top left corner of Python console click on 'File' -> 'New'->'Terminal'
#
#    2. You will be requiered to navigate across your directories using terminal commands. A quick guide on how to navigate the directory can be found following this [link](https://riptutorial.com/terminal/example/26023/basic-navigation-commands). You will need to place you directory in the folder in which the app files are located. If you paste this folder in your hard drive :C your terminal command should look like :
#         <code> C:\KSU-WHEAT-APP> </code>
#    3. Once you succesfully reached the correct folder you will need to run the following command:
#         <code> streamlit run main.py </code>
#    4. The aforementioned command should automatically launch the app. However if it does not lauch automatically you can use any of the links provided:
#
#         <code> Local URL: http://localhost:8503<code>
#         <code> Network URL: http://129.130.90.72:8503<code>
#    5. If you are accesing the app through your cell phone or through a different IP address as the one the computer from the lab is connected you should run the 'Network URL' link. This is important, otherwise tha app will not run.

# %% [markdown]
# ## Surfing the app!
#
# ### Labels Generator App
#
#    This app was deployed with the objective of having a unique identifier for each of the samples we generate in our laboratory. Shortly, this app generates a label of the following format:
#    <center>**TRIAL-LOCATION-YEAR-TIME OF SAMPLING-PLOT NUMBER**<center>
#
#   The first step is to lauch the generator by loading the file named **LABELS_INPUT**.This file is contained in the app folder, or cna be loaded from a different directory. The uploader supports two different formats <code> .csv & .xlsx <code>
#
#    By clicking on **GENERATE LABELS** the software will automatically generate labels for the trials uploaded in the LABELS file. We are currently working on develpoment of a tool for systematically upload the information to the LABELS file. This will allow us to be consistent on the way we generate information across the following years.
#
#    Next step is to apply filters depending on the labels the user needs to print. Right after, specify the file name you want to save the labels in
#
#    By clickng on **DOWNLOAD LABELS** a pdf file will be generated containing the labels you generated.

# %% [markdown]
# ### Data Uploading App
#
#    The following app can be used for uploading data generated during data collection for **wheat yield components determination**. A QR code scanner is required for making correct use of this app. If you are having struggles in making the QR scanner work please visit this website. If by any chance the QR scanner stops working you can get a new one [here](https://www.amazon.com/dp/B0855MQ9Y6/ref=redir_mobile_desktop?_encoding=UTF8&aaxitk=b833172e9fc3f01c4b1be96d907c0a82&hsa_cr_id=8851932730701&pd_rd_plhdr=t&pd_rd_r=bc113f11-17f7-4088-8e77-5e88cfec821e&pd_rd_w=z9eUL&pd_rd_wg=LSiJ7&ref_=sbx_be_s_sparkle_lsi4d_asin_0_img).
#
#    The data will be saved on a file called data.csv

# %% [markdown]
# ## Canopy Cover Data Uploading App
#
# This app was deployed for efficient processing of canopy cover images. The input code was based on:
#
# Patrignani, A. and Ochsner, T.E., 2015. Canopeo: A powerful new tool for measuring fractional green canopy cover. Agronomy Journal, 107(6), pp.2312-2320
#
# For using the app you will need a GoPro camera which you can connect into you smartphone. You will need an android smartphone, otherwise the QR scanner would be unavailable.
#
# #### Steps:
#
#  1. Scan QR code in the plot stake
#
#  2. Load the most recent file corresponded to the last picture you have taken with the Go Pro camera.
#
#  3. Select the developmental stage of the crop at the moment you are taking the canopy picture.
#
#  4. Click on LOAD CANOPY COVER DATAPOINT. By clicking this button the app will automatically process an algorithm to estimate canopy cover and save the datapoint in the computer in which you have the app running

# %% [markdown]
# ## Seed Counter and TKW calculation App
#
# This section of the app is still immature. Please, apologies for debugs that might be present on it.
#
# Shortly, this app runs an algorithm that detects each individual wheat grain placed over a white surface. Some considerations:
#
#    1. Make sure the backgroud does not include anything more then a white colors. For achieving this you can put together mutiple white paper sheets.
#    2. The image of the grains should be taken from the top lined up as much parallel as posible with the surface in which grain are located.
#    3. **AVOID SHADINGS!** Make sure when you are taking the picture no shades are present
#    4. Once you have the picture ready you can double check the grains arrangement on your paper sheet by clicking on **Check Grains Arrangement**. An image showing the grians contours will be displayed. If it does not similar to the pattern of grain the **picture needs to be re-taken or grains need to be re-arranged**
#    5. By clicking on **LOAD TKW DATAPOINT**, it will run a chunk of code for loading TKW data into a pre-determined file.

# %% [markdown]
# # HARDWARE REQUIRED
#
# ## <center> PRINTERS <center>
#
# Device required: **Brother QL-820NWB**
#
# By seaching for "Printers & scanners" in your search box in Windows, then navigating into Printer Preferences you can set the label size you want to print.  **BIG labels default size is 2.4"(h) x 3.9"(w). SMALL labels are 1.4"(h) x 3.5"(w)**.

# %% [markdown]
# ## <center> QR CODE SCANNER <center>
#
# #### Setting the QR scanner to your smartphone or computer
#
#   The labels can be read easy and fast with a [NETUM C750 QR CODE SCANNER](https://www.netum.net/es/pages/barcode-scanner-user-manuals). By following this [link](https://cdn.shopify.com/s/files/1/2144/8019/files/NETUM_C_Series_Quick_Start_Manual.pdf?v=1644138901) you can get access to the users guide. Shorly, you can scan the 2nd available barcode on the guide to set UBS mode in your computer (make sure you plugged in the USB port). If you are working from an Android smartphone you can connect via Bluetooth by scanning the 5th barcode in the users guide.
#
#   When using the QR scanner in your Android smartphonne the keyboard language needs to be set to **ENGLISH**
